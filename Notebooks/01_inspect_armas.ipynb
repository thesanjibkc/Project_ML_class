# %%
#import pandas for reading and exploring the  data
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Load the ARMAS datasets from the raw data folder
armas1 = pd.read_json(r'D:\Project_ML_class\data\raw\ARMAS_STATIC_20132023_P1_altD.json', lines = True)
armas2 = pd.read_json(r'D:\Project_ML_class\data\raw\ARMAS_STATIC_20132023_P2_altD.json', lines = True) 
armas3 = pd.read_json(r'D:\Project_ML_class\data\raw\ARMAS_STATIC_20132023_P3_altD.json', lines = True)

# %%
# Check the size of the datasets
# shape returns (number_of _rows, number_of_columns)
print("armas1 shape:", armas1.shape)
print("armas2 shape:", armas2.shape)
print("armas3 shape:", armas3.shape)
# Out:
# armas1 shape: (32380, 49)
# armas2 shape: (30787, 49)
# armas3 shape: (29309, 49)

# %%
# Inspect column names to understand the structure of the data
print(armas1.columns)
# Out:
# Index(['Datetime', 'ARMAS', 'NAIRASV3', 'NAIRASV2', 'Latitude', 'Longitude',
#        'Altitude(Bar)', 'Altitude(GPS)', 'Geomagnetic_latitude',
#        'Geomagnetic_longitude', 'Geomagnetic_Rc', 'Geomagnetic_Lshell',
#        'NM_NEWK', 'NM_OULU', 'NM_THUL', 'NM_SOPO', 'SXR_short', 'SXR_long',
#        'Particles_P1', 'Particles_P5', 'Particles_P10', 'Particles_P30',
#        'Particles_P50', 'Particles_P100', 'Particles_E20', 'SW_B', 'SW_Bx',
#        'SW_By', 'SW_Bz', 'SW_V', 'SW_Vx', 'SW_Vy', 'SW_Vz', 'SW_density',
#        'SW_temperature', 'SW_pressure', 'Index_Kp', 'Index_Dst', 'Index_Ap',
#        'Vehicle_ID', 'Solar_sunspots', 'Solar_f107', 'Solar_NPF', 'Solar_SPF',
#        'Solar_APF', 'Solar_NPF20', 'Solar_SPF20', 'Solar_APF20', 'Index_D'],
#       dtype='object')

# %%
armas_all = pd.concat([armas1, armas2, armas3], ignore_index=True)
print(armas_all.shape)
print(armas_all.columns)
# Out:
# (92476, 49)
# Index(['Datetime', 'ARMAS', 'NAIRASV3', 'NAIRASV2', 'Latitude', 'Longitude',
#        'Altitude(Bar)', 'Altitude(GPS)', 'Geomagnetic_latitude',
#        'Geomagnetic_longitude', 'Geomagnetic_Rc', 'Geomagnetic_Lshell',
#        'NM_NEWK', 'NM_OULU', 'NM_THUL', 'NM_SOPO', 'SXR_short', 'SXR_long',
#        'Particles_P1', 'Particles_P5', 'Particles_P10', 'Particles_P30',
#        'Particles_P50', 'Particles_P100', 'Particles_E20', 'SW_B', 'SW_Bx',
#        'SW_By', 'SW_Bz', 'SW_V', 'SW_Vx', 'SW_Vy', 'SW_Vz', 'SW_density',
#        'SW_temperature', 'SW_pressure', 'Index_Kp', 'Index_Dst', 'Index_Ap',
#        'Vehicle_ID', 'Solar_sunspots', 'Solar_f107', 'Solar_NPF', 'Solar_SPF',
#        'Solar_APF', 'Solar_NPF20', 'Solar_SPF20', 'Solar_APF20', 'Index_D'],
#       dtype='object')

# %%
armas_all.describe()
# Out:
#               ARMAS      NAIRASV3      NAIRASV2      Latitude     Longitude  \
# count  92476.000000  92476.000000  92476.000000  92476.000000  92476.000000
# mean       9.643342      9.764880      5.967949     13.166842    -82.565163
# std        5.364425      3.595358      2.516188     42.435218     54.354644
# min        0.046000      1.959000      1.124000    -86.220000   -180.000000
# 25%        4.721000      7.137000      4.362000      5.900000   -112.090000
# 50%        9.271000      9.882000      6.117000     28.400000    -86.035000
# 75%       13.435000     12.000000      7.736000     39.450000    -70.600000
# max       42.385000     27.312000     13.850000     82.000000    180.000000
#
#        Altitude(Bar)  Altitude(GPS)  Geomagnetic_latitude  \
# count   92476.000000   92476.000000          92476.000000
# mean    11055.043295   11499.511650             20.114878
# std      1842.058479    1671.327956             41.355686
# min      8000.010000    8000.000000            -76.620000
# 25%      9543.405000   10241.280000             12.800000
# 50%     10698.010000   11277.600000             36.630000
# 75%     12887.337500   13100.000000             46.970000
# max     15498.550000   16272.360000             88.420000
#
#        Geomagnetic_longitude  Geomagnetic_Rc  ...      Index_Ap  \
# count           92476.000000    92476.000000  ...  92476.000000
# mean              -21.400578        4.050419  ...     10.321305
# std                44.870526        3.360314  ...     15.663195
# min              -166.620000        0.000000  ...      0.000000
# 25%               -47.470000        1.610000  ...      3.000000
# 50%               -15.550000        3.280000  ...      5.000000
# 75%                 0.300000        5.420000  ...     12.000000
# max               166.250000       13.120000  ...    236.000000
#
#        Solar_sunspots    Solar_f107     Solar_NPF     Solar_SPF     Solar_APF  \
# count    92476.000000  92476.000000  92476.000000  92476.000000  92476.000000
# mean        32.188233     86.148469     51.410296    -54.599417     53.092127
# std         36.656100     22.727240     28.278057     23.878630     15.382372
# min          0.000000     65.500000    -21.000000   -103.000000      4.000000
# 25%          0.000000     69.800000     30.000000    -71.000000     46.000000
# 50%         16.000000     76.300000     52.000000    -47.000000     58.000000
# 75%         49.000000     97.500000     75.000000    -40.000000     64.000000
# max        206.000000    220.700000    104.000000     12.857142     71.000000
#
#         Solar_NPF20   Solar_SPF20   Solar_APF20       Index_D
# count  92476.000000  92476.000000  92476.000000  92476.000000
# mean      46.669535    -61.936573     54.313189      1.144178
# std       21.019098     17.870065     14.838726      0.898087
# min       -2.000000    -82.000000      5.000000      0.000000
# 25%       29.000000    -72.000000     53.000000      0.000000
# 50%       53.000000    -68.000000     61.000000      1.000000
# 75%       64.000000    -56.000000     64.000000      2.000000
# max       74.000000      2.000000     65.000000      4.000000
#
# [8 rows x 47 columns]

# %%
armas_all['Index_D'].describe()
# Out:
# count    92476.000000
# mean         1.144178
# std          0.898087
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          4.000000
# Name: Index_D, dtype: float64

# %%
armas_all['Index_D'].value_counts()
# plt.xlabel('Index_D')
# plt.ylabel('Count')
# plt.title('Distribution of index_D')
# plt.show()
# Out:
# Index_D
# 2    31586
# 1    29314
# 0    27137
# 3     4433
# 4        6
# Name: count, dtype: int64

# %%
print("armas1")
print(armas1['Index_D'].value_counts().sort_index())

print("\narmas2")
print(armas2['Index_D'].value_counts().sort_index())

print("\narmas3")
print(armas3['Index_D'].value_counts().sort_index())
# Out:
# armas1
# Index_D
# 0     8871
# 1    10297
# 2    11780
# 3     1428
# 4        4
# Name: count, dtype: int64
#
# armas2
# Index_D
# 0     9452
# 1     9766
# 2    10062
# 3     1507
# Name: count, dtype: int64
#
# armas3
# Index_D
# 0    8814
# 1    9251
# 2    9744
# 3    1498
# 4       2
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))

armas1['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[0], title='armas1')
armas2['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[1], title='armas2')
armas3['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[2], title='armas3')

plt.show()

# %%
dist = pd.DataFrame({
    'armas1': armas1['Index_D'].value_counts(),
    'armas2': armas2['Index_D'].value_counts(),
    'armas3': armas3['Index_D'].value_counts()
}).fillna(0).sort_index()

print(dist)
# Out:
#          armas1   armas2  armas3
# Index_D
# 0          8871   9452.0    8814
# 1         10297   9766.0    9251
# 2         11780  10062.0    9744
# 3          1428   1507.0    1498
# 4             4      0.0       2

# %%
armas_all = pd.concat([armas1, armas2, armas3], ignore_index=True)

# %%
bins = [0,5,15,45]
labels =range(len(bins)-1)

# %%
dfs = {
    'armas1': armas1,
    'armas2': armas2,
    'armas3': armas3,
    'armas_all': armas_all
}

# %%
for name, df in dfs.items():
    df['Index_D'] = pd.cut(
        df['ARMAS'],
        bins=bins,
        labels=labels,
        right=False
    )

# %%
armas1.head()
# Out:
#                    Datetime  ARMAS  NAIRASV3  NAIRASV2  Latitude  Longitude  \
# 0 2013-06-28 03:00:18+00:00  5.995     3.936     1.709     12.20    -121.10
# 1 2013-06-28 03:03:15+00:00  3.597     3.942     1.734     12.50    -120.90
# 2 2013-06-28 03:04:13+00:00  3.597     3.954     1.734     12.57    -120.83
# 3 2013-06-28 03:05:12+00:00  3.597     3.931     1.734     12.63    -120.77
# 4 2013-06-28 03:06:11+00:00  3.597     3.956     1.734     12.70    -120.70
#
#    Altitude(Bar)  Altitude(GPS)  Geomagnetic_latitude  Geomagnetic_longitude  \
# 0       12795.29        12800.0                 18.44                 -50.50
# 1       12820.86        12800.0                 18.77                 -50.34
# 2       12798.12        12800.0                 18.84                 -50.28
# 3       12753.43        12800.0                 18.92                 -50.22
# 4       12769.70        12800.0                 18.99                 -50.17
#
#    ...  Vehicle_ID  Solar_sunspots  Solar_f107  Solar_NPF  Solar_SPF  \
# 0  ...       (AFRC              75       104.3        2.0       -8.0
# 1  ...       (AFRC              75       104.3        2.0       -8.0
# 2  ...       (AFRC              75       104.3        2.0       -8.0
# 3  ...       (AFRC              75       104.3        2.0       -8.0
# 4  ...       (AFRC              75       104.3        2.0       -8.0
#
#    Solar_APF  Solar_NPF20  Solar_SPF20  Solar_APF20  Index_D
# 0        5.0         11.0          2.0          5.0        1
# 1        5.0         11.0          2.0          5.0        0
# 2        5.0         11.0          2.0          5.0        0
# 3        5.0         11.0          2.0          5.0        0
# 4        5.0         11.0          2.0          5.0        0
#
# [5 rows x 49 columns]

# %%
armas1.columns
# Out:
# Index(['Datetime', 'ARMAS', 'NAIRASV3', 'NAIRASV2', 'Latitude', 'Longitude',
#        'Altitude(Bar)', 'Altitude(GPS)', 'Geomagnetic_latitude',
#        'Geomagnetic_longitude', 'Geomagnetic_Rc', 'Geomagnetic_Lshell',
#        'NM_NEWK', 'NM_OULU', 'NM_THUL', 'NM_SOPO', 'SXR_short', 'SXR_long',
#        'Particles_P1', 'Particles_P5', 'Particles_P10', 'Particles_P30',
#        'Particles_P50', 'Particles_P100', 'Particles_E20', 'SW_B', 'SW_Bx',
#        'SW_By', 'SW_Bz', 'SW_V', 'SW_Vx', 'SW_Vy', 'SW_Vz', 'SW_density',
#        'SW_temperature', 'SW_pressure', 'Index_Kp', 'Index_Dst', 'Index_Ap',
#        'Vehicle_ID', 'Solar_sunspots', 'Solar_f107', 'Solar_NPF', 'Solar_SPF',
#        'Solar_APF', 'Solar_NPF20', 'Solar_SPF20', 'Solar_APF20', 'Index_D'],
#       dtype='object')

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))

armas1['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[0], title='armas1')
armas2['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[1], title='armas2')
armas3['Index_D'].value_counts().sort_index().plot(kind='bar', ax=axes[2], title='armas3')

plt.show()

# %%
armas1 = armas1.rename(columns={'Index_D': 'Index_K'})
armas2 = armas2.rename(columns={'Index_D': 'Index_K'})
armas3 = armas3.rename(columns={'Index_D': 'Index_K'})
armas_all = armas_all.rename(columns={'Index_D': 'Index_K'})

# %%
armas1 = armas1.rename(columns={'Index_D': 'Index_K'})
armas2 = armas2.rename(columns={'Index_D': 'Index_K'})
armas3 = armas3.rename(columns={'Index_D': 'Index_K'})
armas_all = armas_all.rename(columns={'Index_D': 'Index_K'})

# %%
# STEP 1: Rename Index_D → Index_K (in-place)
for df in [armas1, armas2, armas3, armas_all]:
    df.rename(columns={'Index_D': 'Index_K'}, inplace=True)

# STEP 2: Create subplot grid (2x2)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# STEP 3: Define colors for bins
colors = ['#4CAF50', '#2196F3', '#FF9800']

# STEP 4: Store datasets with names
dfs = [
    ('armas1', armas1),
    ('armas2', armas2),
    ('armas3', armas3),
    ('armas_all', armas_all)
]

# STEP 5: Flatten axes (important)
axes = axes.flatten()

# STEP 6: Loop and plot
for i, (name, df) in enumerate(dfs):
    
    # Count values
    counts = df['Index_K'].value_counts().sort_index()
    
    # Plot bar chart
    counts.plot(
        kind='bar',
        ax=axes[i],
        color=colors
    )
    
    # Special styling for armas_all
    if name == 'armas_all':
        axes[i].set_title(name.upper(), fontsize=12, fontweight='bold')
        axes[i].set_facecolor('#f0f0f0')
    else:
        axes[i].set_title(name)
    
    # Labels
    axes[i].set_xlabel('Index_K')
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=0)

    # STEP 7: Add values on top of bars
    for j, value in enumerate(counts):
        axes[i].text(
            j, value,
            str(value),
            ha='center',
            va='bottom'
        )

# STEP 8: Adjust layout
plt.tight_layout()

# plt.savefig(r'D:\Project_ML_class\Results\charts\Index_K_distribution.png', dpi=300)

# STEP 9: Show plot
plt.show()

# %%
armas1.to_csv(r'D:\Project_ML_class\data\processed\armas1_processed.csv', index=False)
armas2.to_csv(r'D:\Project_ML_class\data\processed\armas2_processed.csv', index=False)
armas3.to_csv(r'D:\Project_ML_class\data\processed\armas3_processed.csv', index=False)
armas_all.to_csv(r'D:\Project_ML_class\data\processed\armas_all_processed.csv', index=False)

print("✅ Processed data saved!")
# Out:
# ✅ Processed data saved!
